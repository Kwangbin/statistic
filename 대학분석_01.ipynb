# %% [markdown]
# <a href="https://colab.research.google.com/github/Kwangbin/statistic/blob/main/%EB%8C%80%ED%95%99%EB%B6%84%EC%84%9D_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. matplotlib version updgrade (v3.2.2 to v3.4.1)
# !pip install matplotlib -U
import matplotlib as mpl
mpl.__version__

# 2. 한글 폰트 설치
# https://velog.io/@jgpark1998/Colab-%ED%95%9C%EA%B8%80-%EA%B9%A8%EC%A7%90-RuntimeWarning-%EC%98%A4%EB%A5%98-%ED%95%B4%EA%B2%B0%ED%95%98%EA%B8%B0
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# ...
#      |████████████████████████████████| 11.2 MB 7.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 60.4 MB/s
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   cuda-command-line-tools-10-0 cuda-command-line-tools-10-1
#   cuda-command-line-tools-11-0 cuda-compiler-10-0 cuda-compiler-10-1
#   cuda-compiler-11-0 cuda-cuobjdump-10-0 cuda-cuobjdump-10-1
# ...

# %%
#런타임 다시시작

# %%
cd drive/MyDrive/academy/적립금
# Out:
# /content/drive/MyDrive/academy/적립금

# %%
ls
# Out:
#  적립금_002.xlsx
#  적립금_15_21.xlsx
#  적립금_15to21.xlsx
# '2015년 _대학_8-사. 적립금 현황_학교별자료.xlsx'
#  2015_적립금_교비.xlsx
#  2015_적립금_법인.xlsx
# '2016년 _대학_8-사. 적립금 현황_학교별자료.xlsx'
#  2016_적립금_교비.xlsx
#  2016_적립금_법인.xlsx
# '2017년 _대학_8-사. 적립금 현황_학교별자료.xlsx'
#  2017_적립금_교비.xlsx
#  2017_적립금_법인.xlsx
# '2018년 _대학_8-사. 적립금 현황_학교별자료.xlsx'
#  2018_적립금_교비.xlsx
#  2018_적립금_법인.xlsx
# '2019년 _대학_8-사. 적립금 현황_학교별자료.xlsx'
#  2019_적립금_교비.xlsx
#  2019_적립금_법인.xlsx
# '2020년 _대학_8-사. 적립금 현황_학교별자료.xlsx'
#  2020_적립금_교비.xlsx
#  2020_적립금_법인.xlsx
# '2021년 _대학_8-사. 적립금 현황_학교별자료.xlsx'
#  2021_적립금_교비.xlsx
#  2021_적립금_법인.xlsx

# %%
#4. import libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# 한글 사용
plt.rc('font', family='NanumBarunGothic') 

#5. 한글 출력 확인
# 한글폰트 확인하기
pd.Series([1, 3, 5, -7, 9]).plot(title="한글폰트")
# Out:
# <AxesSubplot:title={'center':'한글폰트'}>
# /usr/local/lib/python3.7/dist-packages/google/colab/_event_manager.py:28: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py:125: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df=pd.read_excel('적립금_002.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        학교명  ...  2019_증감률_순위  2020_증감률_순위  2021_증감률_순위
# 0           0             0  가야대학교(김해)  ...        147.0          1.0        102.0
# 1           1             1      가천대학교  ...         14.0         35.0         18.0
# 2           2             2   가톨릭관동대학교  ...          4.0         14.0         12.0
# 3           3             3  가톨릭꽃동네대학교  ...        117.0         67.0         73.0
# 4           4             4     가톨릭대학교  ...         18.0         54.0        127.0
#
# [5 rows x 35 columns]

# %%
df=df.drop(['Unnamed: 0','Unnamed: 0.1'], axis=1)
df.head()
# Out:
#          학교명      2015_적립금  2015_순위  ...  2019_증감률_순위  2020_증감률_순위  2021_증감률_순위
# 0  가야대학교(김해)  1.559898e+10     85.0  ...        147.0          1.0        102.0
# 1      가천대학교  7.245236e+10     32.0  ...         14.0         35.0         18.0
# 2   가톨릭관동대학교  2.285032e+10     72.0  ...          4.0         14.0         12.0
# 3  가톨릭꽃동네대학교  4.218378e+09    111.0  ...        117.0         67.0         73.0
# 4     가톨릭대학교  9.696377e+10     21.0  ...         18.0         54.0        127.0
#
# [5 rows x 33 columns]

# %%
df1 =df.set_index("학교명")

# %%
df1.head()
# Out:
#                2015_적립금  2015_순위  ...  2020_증감률_순위  2021_증감률_순위
# 학교명                               ...
# 가야대학교(김해)  1.559898e+10     85.0  ...          1.0        102.0
# 가천대학교      7.245236e+10     32.0  ...         35.0         18.0
# 가톨릭관동대학교   2.285032e+10     72.0  ...         14.0         12.0
# 가톨릭꽃동네대학교  4.218378e+09    111.0  ...         67.0         73.0
# 가톨릭대학교     9.696377e+10     21.0  ...         54.0        127.0
#
# [5 rows x 32 columns]

# %%
df1.sort_values('2020_증감률').head(20)
# Out:
#                  2015_적립금  2015_순위  ...  2020_증감률_순위  2021_증감률_순위
# 학교명                                 ...
# 대전신학대학교      2.190850e+08    148.0  ...        157.0          NaN
# 추계예술대학교      2.885352e+09    119.0  ...        156.0         72.0
# 한양사이버대학교     2.883400e+10     63.0  ...        155.0         46.0
# 사이버한국외국어대학교  6.799952e+09    103.0  ...        154.0         25.0
# 칼빈대학교        1.723340e+08    149.0  ...        153.0         13.0
# 예수대학교        7.570000e+08    137.0  ...        152.0        160.0
# 극동대학교        7.000000e+07    155.0  ...        151.0        158.0
# 서울기독대학교      0.000000e+00    163.0  ...        150.0          NaN
# 한일장신대학교      9.204028e+09     96.0  ...        149.0        153.0
# 부산장신대학교      1.800594e+09    128.0  ...        148.0         67.0
# 한라대학교        7.312200e+07    154.0  ...        147.0          6.0
# 명지대학교        4.050085e+10     52.0  ...        146.0        157.0
# 한국성서대학교      2.238592e+09    125.0  ...        145.0         38.0
# ...

# %%
df2 = df1.astype('int32')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-31-4ec89b797d10> in <module>()
# ----> 1 df2 = df1.astype('int32')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df1.isnull()
# Out:
#                   2015_적립금  2015_순위  ...  2020_증감률_순위  2021_증감률_순위
# 학교명                                  ...
# 가야대학교(김해)            False    False  ...        False        False
# 가천대학교                False    False  ...        False        False
# 가톨릭관동대학교             False    False  ...        False        False
# 가톨릭꽃동네대학교            False    False  ...        False        False
# 가톨릭대학교               False    False  ...        False        False
# ...                    ...      ...  ...          ...          ...
# 건국대학교(글로컬) _분교        True     True  ...         True        False
# 고려대학교(세종) _분교         True     True  ...         True        False
# 동국대학교(경주) _분교         True     True  ...         True        False
# 연세대학교(미래) _분교         True     True  ...         True        False
# 한양대학교(ERICA) _분교      True     True  ...         True        False
#
# [180 rows x 32 columns]

# %%
df1
# Out:
#                       2015_적립금  2015_순위  ...  2020_증감률_순위  2021_증감률_순위
# 학교명                                      ...
# 가야대학교(김해)         1.559898e+10     85.0  ...          1.0        102.0
# 가천대학교             7.245236e+10     32.0  ...         35.0         18.0
# 가톨릭관동대학교          2.285032e+10     72.0  ...         14.0         12.0
# 가톨릭꽃동네대학교         4.218378e+09    111.0  ...         67.0         73.0
# 가톨릭대학교            9.696377e+10     21.0  ...         54.0        127.0
# ...                        ...      ...  ...          ...          ...
# 건국대학교(글로컬) _분교             NaN      NaN  ...          NaN          1.0
# 고려대학교(세종) _분교              NaN      NaN  ...          NaN          2.0
# 동국대학교(경주) _분교              NaN      NaN  ...          NaN          3.0
# 연세대학교(미래) _분교              NaN      NaN  ...          NaN          4.0
# 한양대학교(ERICA) _분교           NaN      NaN  ...          NaN          5.0
#
# [180 rows x 32 columns]

# %%
# replace 메서드로 np.inf를 None(np.nan)으로 변경
df2 = df1.replace([np.inf, -np.inf], np.nan)

# %%
df2
# Out:
#                       2015_적립금  2015_순위  ...  2020_증감률_순위  2021_증감률_순위
# 학교명                                      ...
# 가야대학교(김해)         1.559898e+10     85.0  ...          1.0        102.0
# 가천대학교             7.245236e+10     32.0  ...         35.0         18.0
# 가톨릭관동대학교          2.285032e+10     72.0  ...         14.0         12.0
# 가톨릭꽃동네대학교         4.218378e+09    111.0  ...         67.0         73.0
# 가톨릭대학교            9.696377e+10     21.0  ...         54.0        127.0
# ...                        ...      ...  ...          ...          ...
# 건국대학교(글로컬) _분교             NaN      NaN  ...          NaN          1.0
# 고려대학교(세종) _분교              NaN      NaN  ...          NaN          2.0
# 동국대학교(경주) _분교              NaN      NaN  ...          NaN          3.0
# 연세대학교(미래) _분교              NaN      NaN  ...          NaN          4.0
# 한양대학교(ERICA) _분교           NaN      NaN  ...          NaN          5.0
#
# [180 rows x 32 columns]

# %%
df2.fillna(value=1)
# Out:
#                       2015_적립금  2015_순위  ...  2020_증감률_순위  2021_증감률_순위
# 학교명                                      ...
# 가야대학교(김해)         1.559898e+10     85.0  ...          1.0        102.0
# 가천대학교             7.245236e+10     32.0  ...         35.0         18.0
# 가톨릭관동대학교          2.285032e+10     72.0  ...         14.0         12.0
# 가톨릭꽃동네대학교         4.218378e+09    111.0  ...         67.0         73.0
# 가톨릭대학교            9.696377e+10     21.0  ...         54.0        127.0
# ...                        ...      ...  ...          ...          ...
# 건국대학교(글로컬) _분교    1.000000e+00      1.0  ...          1.0          1.0
# 고려대학교(세종) _분교     1.000000e+00      1.0  ...          1.0          2.0
# 동국대학교(경주) _분교     1.000000e+00      1.0  ...          1.0          3.0
# 연세대학교(미래) _분교     1.000000e+00      1.0  ...          1.0          4.0
# 한양대학교(ERICA) _분교  1.000000e+00      1.0  ...          1.0          5.0
#
# [180 rows x 32 columns]

# %%
df2.isnull()
# Out:
#                   2015_적립금  2015_순위  ...  2020_증감률_순위  2021_증감률_순위
# 학교명                                  ...
# 가야대학교(김해)            False    False  ...        False        False
# 가천대학교                False    False  ...        False        False
# 가톨릭관동대학교             False    False  ...        False        False
# 가톨릭꽃동네대학교            False    False  ...        False        False
# 가톨릭대학교               False    False  ...        False        False
# ...                    ...      ...  ...          ...          ...
# 건국대학교(글로컬) _분교        True     True  ...         True        False
# 고려대학교(세종) _분교         True     True  ...         True        False
# 동국대학교(경주) _분교         True     True  ...         True        False
# 연세대학교(미래) _분교         True     True  ...         True        False
# 한양대학교(ERICA) _분교      True     True  ...         True        False
#
# [180 rows x 32 columns]

# %%
|df3 = df2.astype('int32')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-36-bbcf10e90725> in <module>()
# ----> 1 df3 = df2.astype('int32')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df1.isnull()
# Out:
#                   2015_적립금  2015_순위  ...  2020_증감률_순위  2021_증감률_순위
# 학교명                                  ...
# 가야대학교(김해)            False    False  ...        False        False
# 가천대학교                False    False  ...        False        False
# 가톨릭관동대학교             False    False  ...        False        False
# 가톨릭꽃동네대학교            False    False  ...        False        False
# 가톨릭대학교               False    False  ...        False        False
# ...                    ...      ...  ...          ...          ...
# 건국대학교(글로컬) _분교        True     True  ...         True        False
# 고려대학교(세종) _분교         True     True  ...         True        False
# 동국대학교(경주) _분교         True     True  ...         True        False
# 연세대학교(미래) _분교         True     True  ...         True        False
# 한양대학교(ERICA) _분교      True     True  ...         True        False
#
# [180 rows x 32 columns]

# %%
df
